# %% [markdown]
# <a href="https://colab.research.google.com/github/Greg-Saul/DL_HW/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-0ch0lwi8
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-0ch0lwi8
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=e8a88a69a11bb13e7b9d7ea470b5fff94b72913892787768ab3ea7aa417f6419
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7n7qz_74/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  # def forward(self, x):
  #   h1 = self.linear1(x).relu()
  #   h2 = self.linear2(h1).relu()
  #   h3 = self.linear3(h2).relu()
  #   return self.linear4(h3)

  def forward(self, x):
    h1 = self.linear1(x)
    h2 = h1 + self.linear2(h1.relu())
    h3 = h2 + self.linear3(h2.relu())
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.679635, train error 62.47,  val loss 1.766600, percent error 66.60
# Epoch     1, train loss 1.177824, train error 45.10,  val loss 1.382518, percent error 53.90
# Epoch     2, train loss 1.000772, train error 38.12,  val loss 1.222537, percent error 47.30
# Epoch     3, train loss 0.986318, train error 38.00,  val loss 1.273529, percent error 47.70
# Epoch     4, train loss 0.792015, train error 30.03,  val loss 1.164243, percent error 43.40
# Epoch     5, train loss 0.744597, train error 28.05,  val loss 1.143407, percent error 42.60
# Epoch     6, train loss 0.675147, train error 25.65,  val loss 1.145497, percent error 42.40
# Epoch     7, train loss 0.633187, train error 23.47,  val loss 1.150867, percent error 41.80
# Epoch     8, train loss 0.577926, train error 22.25,  val loss 1.091417, percent error 37.90
# Epoch     9, train loss 0.522675, train error 20.22,  val loss 1.179434, percent error 38.50
# Epoch    10, train loss 0.482887, train error 18.80,  val loss 1.230648, percent error 39.00
# Epoch    11, train loss 0.410549, train error 15.30,  val loss 1.180137, percent error 36.50
# Epoch    12, train loss 0.416647, train error 15.82,  val loss 1.195158, percent error 36.50
# Epoch    13, train loss 0.370914, train error 13.32,  val loss 1.358316, percent error 37.20
# Epoch    14, train loss 0.377724, train error 13.45,  val loss 1.339388, percent error 37.40
# Epoch    15, train loss 0.344525, train error 12.40,  val loss 1.329763, percent error 36.70
# Epoch    16, train loss 0.260745, train error 9.65,  val loss 1.428998, percent error 34.90
# Epoch    17, train loss 0.313394, train error 11.20,  val loss 1.545656, percent error 36.00
# Epoch    18, train loss 0.306938, train error 11.10,  val loss 1.539258, percent error 35.40
# Epoch    19, train loss 0.468674, train error 15.50,  val loss 1.719096, percent error 38.20
# Epoch    20, train loss 0.114231, train error 3.43,  val loss 1.308005, percent error 31.70
# Epoch    21, train loss 0.050425, train error 0.88,  val loss 1.293330, percent error 32.50
# Epoch    22, train loss 0.028074, train error 0.18,  val loss 1.260505, percent error 31.10
# Epoch    23, train loss 0.019506, train error 0.05,  val loss 1.299957, percent error 31.20
# Epoch    24, train loss 0.014462, train error 0.00,  val loss 1.340487, percent error 30.50
# Epoch    25, train loss 0.011794, train error 0.00,  val loss 1.359770, percent error 30.60
# Epoch    26, train loss 0.010203, train error 0.00,  val loss 1.394305, percent error 30.70
# Epoch    27, train loss 0.008835, train error 0.00,  val loss 1.407362, percent error 30.40
# Epoch    28, train loss 0.007827, train error 0.00,  val loss 1.426184, percent error 30.20
# Epoch    29, train loss 0.007053, train error 0.00,  val loss 1.446178, percent error 30.70
# Epoch    30, train loss 0.006448, train error 0.00,  val loss 1.461284, percent error 30.70
# Epoch    31, train loss 0.005906, train error 0.00,  val loss 1.475854, percent error 30.90
# Epoch    32, train loss 0.005495, train error 0.00,  val loss 1.486487, percent error 30.90
# Epoch    33, train loss 0.005071, train error 0.00,  val loss 1.503963, percent error 30.70
# Epoch    34, train loss 0.004735, train error 0.00,  val loss 1.514527, percent error 30.80
# Epoch    35, train loss 0.004453, train error 0.00,  val loss 1.529292, percent error 30.90
# Epoch    36, train loss 0.004200, train error 0.00,  val loss 1.543579, percent error 30.80
# Epoch    37, train loss 0.003950, train error 0.00,  val loss 1.548477, percent error 30.80
# Epoch    38, train loss 0.003741, train error 0.00,  val loss 1.562900, percent error 30.90
# Epoch    39, train loss 0.003542, train error 0.00,  val loss 1.569892, percent error 30.50
# Epoch    40, train loss 0.003453, train error 0.00,  val loss 1.574744, percent error 30.70
# Epoch    41, train loss 0.003372, train error 0.00,  val loss 1.579579, percent error 30.70
# Epoch    42, train loss 0.003295, train error 0.00,  val loss 1.585453, percent error 30.70
# Epoch    43, train loss 0.003220, train error 0.00,  val loss 1.589287, percent error 30.70
# Epoch    44, train loss 0.003149, train error 0.00,  val loss 1.593968, percent error 30.60
# Epoch    45, train loss 0.003081, train error 0.00,  val loss 1.599534, percent error 30.70
# Epoch    46, train loss 0.003015, train error 0.00,  val loss 1.602582, percent error 30.70
# Epoch    47, train loss 0.002953, train error 0.00,  val loss 1.606848, percent error 30.80
# Epoch    48, train loss 0.002892, train error 0.00,  val loss 1.611318, percent error 30.70
# Epoch    49, train loss 0.002834, train error 0.00,  val loss 1.615317, percent error 30.70
# Epoch    50, train loss 0.002778, train error 0.00,  val loss 1.619143, percent error 30.70
# Epoch    51, train loss 0.002724, train error 0.00,  val loss 1.623113, percent error 30.70
# Epoch    52, train loss 0.002671, train error 0.00,  val loss 1.626986, percent error 30.80
# Epoch    53, train loss 0.002621, train error 0.00,  val loss 1.631120, percent error 30.70
# Epoch    54, train loss 0.002573, train error 0.00,  val loss 1.633366, percent error 30.70
# Epoch    55, train loss 0.002526, train error 0.00,  val loss 1.637706, percent error 30.60
# Epoch    56, train loss 0.002481, train error 0.00,  val loss 1.641130, percent error 30.60
# Epoch    57, train loss 0.002438, train error 0.00,  val loss 1.645679, percent error 30.60
# Epoch    58, train loss 0.002394, train error 0.00,  val loss 1.648064, percent error 30.60
# Epoch    59, train loss 0.002354, train error 0.00,  val loss 1.651858, percent error 30.70
# Epoch    60, train loss 0.002333, train error 0.00,  val loss 1.653340, percent error 30.70
# Epoch    61, train loss 0.002314, train error 0.00,  val loss 1.655366, percent error 30.70
# Epoch    62, train loss 0.002294, train error 0.00,  val loss 1.657327, percent error 30.80
# Epoch    63, train loss 0.002276, train error 0.00,  val loss 1.658431, percent error 30.80
# Epoch    64, train loss 0.002257, train error 0.00,  val loss 1.660312, percent error 30.80
# Epoch    65, train loss 0.002239, train error 0.00,  val loss 1.661858, percent error 30.80
# Epoch    66, train loss 0.002221, train error 0.00,  val loss 1.663645, percent error 30.80
# Epoch    67, train loss 0.002203, train error 0.00,  val loss 1.665279, percent error 30.80
# Epoch    68, train loss 0.002186, train error 0.00,  val loss 1.666921, percent error 30.80
# Epoch    69, train loss 0.002168, train error 0.00,  val loss 1.668476, percent error 30.80
# Epoch    70, train loss 0.002151, train error 0.00,  val loss 1.670081, percent error 30.80
# Epoch    71, train loss 0.002134, train error 0.00,  val loss 1.671457, percent error 30.80
# Epoch    72, train loss 0.002118, train error 0.00,  val loss 1.672709, percent error 30.80
# Epoch    73, train loss 0.002101, train error 0.00,  val loss 1.675155, percent error 30.80
# Epoch    74, train loss 0.002086, train error 0.00,  val loss 1.676117, percent error 30.80
# Epoch    75, train loss 0.002070, train error 0.00,  val loss 1.678122, percent error 30.70
# Epoch    76, train loss 0.002054, train error 0.00,  val loss 1.679220, percent error 30.70
# Epoch    77, train loss 0.002039, train error 0.00,  val loss 1.680989, percent error 30.70
# Epoch    78, train loss 0.002024, train error 0.00,  val loss 1.682408, percent error 30.70
# Epoch    79, train loss 0.002009, train error 0.00,  val loss 1.683945, percent error 30.70
# Epoch    80, train loss 0.002001, train error 0.00,  val loss 1.684944, percent error 30.80
# Epoch    81, train loss 0.001994, train error 0.00,  val loss 1.685506, percent error 30.80
# Epoch    82, train loss 0.001986, train error 0.00,  val loss 1.686345, percent error 30.80
# Epoch    83, train loss 0.001979, train error 0.00,  val loss 1.687001, percent error 30.80
# Epoch    84, train loss 0.001972, train error 0.00,  val loss 1.687522, percent error 30.80
# Epoch    85, train loss 0.001965, train error 0.00,  val loss 1.688628, percent error 30.80
# Epoch    86, train loss 0.001958, train error 0.00,  val loss 1.689073, percent error 30.80
# Epoch    87, train loss 0.001951, train error 0.00,  val loss 1.689862, percent error 30.80
# Epoch    88, train loss 0.001944, train error 0.00,  val loss 1.690458, percent error 30.80
# Epoch    89, train loss 0.001937, train error 0.00,  val loss 1.691369, percent error 30.80
# Epoch    90, train loss 0.001930, train error 0.00,  val loss 1.691804, percent error 30.80
# Epoch    91, train loss 0.001923, train error 0.00,  val loss 1.692635, percent error 30.80
# Epoch    92, train loss 0.001916, train error 0.00,  val loss 1.693488, percent error 30.80
# Epoch    93, train loss 0.001910, train error 0.00,  val loss 1.694187, percent error 30.80
# Epoch    94, train loss 0.001903, train error 0.00,  val loss 1.694884, percent error 30.80
# Epoch    95, train loss 0.001896, train error 0.00,  val loss 1.695651, percent error 30.80
# Epoch    96, train loss 0.001890, train error 0.00,  val loss 1.696220, percent error 30.80
# Epoch    97, train loss 0.001883, train error 0.00,  val loss 1.697148, percent error 30.80
# Epoch    98, train loss 0.001877, train error 0.00,  val loss 1.697762, percent error 30.80
# Epoch    99, train loss 0.001870, train error 0.00,  val loss 1.698282, percent error 30.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
#
# Yes, it changes the performance significantly taking the final test error from about 40 to about 30
