# %% [markdown]
# <a href="https://colab.research.google.com/github/Greg-Saul/DL_HW/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-trvavyjk
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-trvavyjk
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
#  - This will happen when The polynomial is a perfect fit that matches the points on the training data meaning, (4000 = 2(D) + 40D + D^2 + 10D) this is just a rough estimate of parameters not exact. when plugging in the equation to desmos it is about 42.
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
#  - This will happen before 42 so perhaps 40
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
#  - This will happen after 42 so perhaps 44

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.304363, train error 89.75,  test loss 2.305301, test error 90.43
# Epoch   100, train loss 2.295534, train error 89.25,  test loss 2.307357, test error 90.03
# Epoch   200, train loss 2.289084, train error 88.82,  test loss 2.307636, test error 89.90
# Epoch   300, train loss 2.283128, train error 88.65,  test loss 2.313604, test error 89.80
# Epoch   400, train loss 2.278878, train error 88.50,  test loss 2.317377, test error 89.82
# Epoch   500, train loss 2.277776, train error 88.50,  test loss 2.327493, test error 89.78
# Epoch   600, train loss 2.273522, train error 88.53,  test loss 2.336445, test error 89.90
# Epoch   700, train loss 2.272649, train error 88.55,  test loss 2.347013, test error 89.88
# Epoch   800, train loss 2.270978, train error 88.55,  test loss 2.353882, test error 89.90
# Epoch   900, train loss 2.270050, train error 88.57,  test loss 2.361693, test error 89.95
# Training model with   4 hidden variables
# Epoch     0, train loss 2.301487, train error 88.57,  test loss 2.306113, test error 88.50
# Epoch   100, train loss 1.871686, train error 69.10,  test loss 1.727525, test error 66.55
# Epoch   200, train loss 1.830724, train error 67.22,  test loss 1.675665, test error 63.20
# Epoch   300, train loss 1.787578, train error 64.00,  test loss 1.629177, test error 61.80
# Epoch   400, train loss 1.785254, train error 63.45,  test loss 1.626240, test error 61.60
# Epoch   500, train loss 1.781313, train error 63.90,  test loss 1.613494, test error 61.42
# Epoch   600, train loss 1.779651, train error 62.88,  test loss 1.618164, test error 60.75
# Epoch   700, train loss 1.800430, train error 64.40,  test loss 1.604856, test error 62.42
# Epoch   800, train loss 1.779427, train error 63.17,  test loss 1.607277, test error 60.65
# Epoch   900, train loss 1.782842, train error 63.40,  test loss 1.628405, test error 61.40
# Training model with   6 hidden variables
# Epoch     0, train loss 2.201669, train error 80.90,  test loss 2.179776, test error 80.57
# Epoch   100, train loss 1.641475, train error 58.55,  test loss 1.444842, test error 56.60
# Epoch   200, train loss 1.612040, train error 57.83,  test loss 1.437049, test error 54.08
# Epoch   300, train loss 1.600843, train error 57.10,  test loss 1.430016, test error 54.85
# Epoch   400, train loss 1.593094, train error 57.20,  test loss 1.426758, test error 54.53
# Epoch   500, train loss 1.588606, train error 56.67,  test loss 1.430804, test error 54.65
# Epoch   600, train loss 1.582755, train error 56.53,  test loss 1.422217, test error 54.85
# Epoch   700, train loss 1.585990, train error 56.55,  test loss 1.430889, test error 55.62
# Epoch   800, train loss 1.581953, train error 56.90,  test loss 1.435143, test error 55.50
# Epoch   900, train loss 1.579808, train error 57.05,  test loss 1.429808, test error 54.95
# Training model with   8 hidden variables
# Epoch     0, train loss 2.274168, train error 84.97,  test loss 2.271157, test error 85.55
# Epoch   100, train loss 1.637169, train error 58.33,  test loss 1.456290, test error 56.58
# Epoch   200, train loss 1.596096, train error 57.38,  test loss 1.445470, test error 55.72
# Epoch   300, train loss 1.574793, train error 56.70,  test loss 1.437184, test error 55.80
# Epoch   400, train loss 1.559069, train error 55.65,  test loss 1.443930, test error 55.03
# Epoch   500, train loss 1.557323, train error 55.65,  test loss 1.466359, test error 56.03
# Epoch   600, train loss 1.550684, train error 55.40,  test loss 1.455950, test error 55.72
# Epoch   700, train loss 1.546103, train error 54.90,  test loss 1.463293, test error 56.03
# Epoch   800, train loss 1.545224, train error 54.92,  test loss 1.472204, test error 55.12
# Epoch   900, train loss 1.539911, train error 55.33,  test loss 1.468653, test error 56.03
# Training model with  10 hidden variables
# Epoch     0, train loss 2.195775, train error 80.30,  test loss 2.163052, test error 79.12
# Epoch   100, train loss 1.495386, train error 50.92,  test loss 1.341966, test error 50.50
# Epoch   200, train loss 1.408059, train error 47.05,  test loss 1.284029, test error 47.20
# Epoch   300, train loss 1.388846, train error 47.08,  test loss 1.289765, test error 46.80
# Epoch   400, train loss 1.372498, train error 46.15,  test loss 1.277884, test error 46.50
# Epoch   500, train loss 1.371107, train error 46.00,  test loss 1.276808, test error 45.95
# Epoch   600, train loss 1.361652, train error 45.50,  test loss 1.282581, test error 46.17
# Epoch   700, train loss 1.360322, train error 45.95,  test loss 1.278970, test error 46.00
# Epoch   800, train loss 1.355976, train error 45.53,  test loss 1.287058, test error 46.45
# Epoch   900, train loss 1.357354, train error 46.05,  test loss 1.294355, test error 46.67
# Training model with  14 hidden variables
# Epoch     0, train loss 2.234190, train error 84.22,  test loss 2.235305, test error 84.22
# Epoch   100, train loss 1.433421, train error 48.00,  test loss 1.330073, test error 49.92
# Epoch   200, train loss 1.357191, train error 46.30,  test loss 1.311269, test error 49.08
# Epoch   300, train loss 1.320233, train error 44.78,  test loss 1.317464, test error 48.92
# Epoch   400, train loss 1.305493, train error 44.28,  test loss 1.320840, test error 48.05
# Epoch   500, train loss 1.293507, train error 44.00,  test loss 1.326921, test error 48.58
# Epoch   600, train loss 1.284173, train error 43.55,  test loss 1.341757, test error 49.45
# Epoch   700, train loss 1.272282, train error 42.78,  test loss 1.352721, test error 49.38
# Epoch   800, train loss 1.266501, train error 42.33,  test loss 1.375389, test error 49.50
# Epoch   900, train loss 1.259515, train error 42.08,  test loss 1.374153, test error 49.65
# Training model with  18 hidden variables
# Epoch     0, train loss 2.263661, train error 84.43,  test loss 2.275739, test error 84.72
# Epoch   100, train loss 1.388254, train error 47.17,  test loss 1.369131, test error 51.28
# Epoch   200, train loss 1.278475, train error 43.38,  test loss 1.359023, test error 49.78
# Epoch   300, train loss 1.223451, train error 41.97,  test loss 1.380878, test error 49.83
# Epoch   400, train loss 1.204490, train error 41.30,  test loss 1.411497, test error 50.35
# Epoch   500, train loss 1.174338, train error 40.05,  test loss 1.439789, test error 50.97
# Epoch   600, train loss 1.167725, train error 39.95,  test loss 1.465421, test error 51.38
# Epoch   700, train loss 1.151063, train error 39.28,  test loss 1.479526, test error 51.58
# Epoch   800, train loss 1.136622, train error 38.55,  test loss 1.507071, test error 52.58
# Epoch   900, train loss 1.127745, train error 38.53,  test loss 1.508305, test error 51.15
# Training model with  22 hidden variables
# Epoch     0, train loss 2.205559, train error 82.10,  test loss 2.181615, test error 81.95
# Epoch   100, train loss 1.248459, train error 41.00,  test loss 1.266221, test error 47.12
# Epoch   200, train loss 1.149063, train error 38.22,  test loss 1.329640, test error 47.97
# Epoch   300, train loss 1.111706, train error 37.15,  test loss 1.432897, test error 50.05
# Epoch   400, train loss 1.061073, train error 35.35,  test loss 1.469520, test error 49.85
# Epoch   500, train loss 1.040718, train error 35.35,  test loss 1.549941, test error 50.20
# Epoch   600, train loss 1.005365, train error 34.70,  test loss 1.597069, test error 50.08
# Epoch   700, train loss 0.999263, train error 34.40,  test loss 1.655825, test error 50.88
# Epoch   800, train loss 0.972217, train error 33.32,  test loss 1.690794, test error 51.38
# Epoch   900, train loss 0.984682, train error 33.97,  test loss 1.776476, test error 52.90
# Training model with  26 hidden variables
# Epoch     0, train loss 2.185240, train error 80.80,  test loss 2.156087, test error 80.47
# Epoch   100, train loss 1.212995, train error 40.08,  test loss 1.340057, test error 49.35
# Epoch   200, train loss 1.061699, train error 35.38,  test loss 1.425289, test error 50.28
# Epoch   300, train loss 0.979222, train error 33.20,  test loss 1.549220, test error 51.95
# Epoch   400, train loss 0.936740, train error 32.15,  test loss 1.652717, test error 52.72
# Epoch   500, train loss 0.895663, train error 30.85,  test loss 1.759380, test error 52.70
# Epoch   600, train loss 0.867025, train error 29.88,  test loss 1.831570, test error 53.08
# Epoch   700, train loss 0.859676, train error 28.93,  test loss 1.925236, test error 53.17
# Epoch   800, train loss 0.833577, train error 28.18,  test loss 2.004321, test error 53.55
# Epoch   900, train loss 0.828059, train error 28.88,  test loss 2.053802, test error 54.42
# Training model with  30 hidden variables
# Epoch     0, train loss 2.151455, train error 80.00,  test loss 2.127697, test error 80.05
# Epoch   100, train loss 1.160421, train error 39.15,  test loss 1.406282, test error 51.72
# Epoch   200, train loss 0.965625, train error 32.57,  test loss 1.603088, test error 52.85
# Epoch   300, train loss 0.859027, train error 29.28,  test loss 1.738709, test error 52.67
# Epoch   400, train loss 0.804691, train error 27.28,  test loss 1.944189, test error 53.90
# Epoch   500, train loss 0.768996, train error 26.68,  test loss 2.124401, test error 54.70
# Epoch   600, train loss 0.763706, train error 26.88,  test loss 2.289580, test error 55.28
# Epoch   700, train loss 0.759942, train error 26.30,  test loss 2.361812, test error 55.88
# Epoch   800, train loss 0.729596, train error 25.80,  test loss 2.491952, test error 56.72
# Epoch   900, train loss 0.732341, train error 25.47,  test loss 2.513994, test error 55.97
# Training model with  35 hidden variables
# Epoch     0, train loss 2.158621, train error 81.15,  test loss 2.125051, test error 79.28
# Epoch   100, train loss 0.982443, train error 31.55,  test loss 1.350457, test error 48.20
# Epoch   200, train loss 0.736325, train error 23.15,  test loss 1.665435, test error 50.20
# Epoch   300, train loss 0.660718, train error 22.07,  test loss 2.055329, test error 51.88
# Epoch   400, train loss 0.596478, train error 20.97,  test loss 2.448324, test error 53.67
# Epoch   500, train loss 0.503509, train error 16.70,  test loss 2.715929, test error 53.17
# Epoch   600, train loss 0.486634, train error 17.22,  test loss 3.113685, test error 53.88
# Epoch   700, train loss 0.475232, train error 16.40,  test loss 3.490778, test error 54.88
# Epoch   800, train loss 0.426625, train error 15.53,  test loss 3.853061, test error 54.50
# Epoch   900, train loss 0.443860, train error 16.18,  test loss 4.220908, test error 54.28
# Training model with  40 hidden variables
# Epoch     0, train loss 2.190311, train error 80.82,  test loss 2.179251, test error 79.90
# Epoch   100, train loss 0.915911, train error 29.10,  test loss 1.386200, test error 48.70
# Epoch   200, train loss 0.655723, train error 20.88,  test loss 1.876552, test error 51.47
# Epoch   300, train loss 0.482542, train error 15.93,  test loss 2.513542, test error 53.55
# Epoch   400, train loss 0.408167, train error 13.12,  test loss 3.188956, test error 55.10
# Epoch   500, train loss 0.330770, train error 11.00,  test loss 3.896653, test error 55.25
# Epoch   600, train loss 0.341052, train error 11.07,  test loss 4.719755, test error 55.60
# Epoch   700, train loss 0.333113, train error 11.03,  test loss 5.328200, test error 55.00
# Epoch   800, train loss 0.238073, train error 8.20,  test loss 5.980744, test error 56.42
# Epoch   900, train loss 0.217894, train error 7.57,  test loss 6.748330, test error 56.95
# Training model with  45 hidden variables
# Epoch     0, train loss 2.093449, train error 79.07,  test loss 2.043791, test error 78.75
# Epoch   100, train loss 0.834577, train error 26.85,  test loss 1.499242, test error 50.33
# Epoch   200, train loss 0.535114, train error 17.62,  test loss 2.231874, test error 53.40
# Epoch   300, train loss 0.341473, train error 10.95,  test loss 3.198229, test error 53.75
# Epoch   400, train loss 0.211010, train error 5.95,  test loss 4.341290, test error 55.38
# Epoch   500, train loss 0.204621, train error 7.38,  test loss 5.635674, test error 55.97
# Epoch   600, train loss 0.144897, train error 4.88,  test loss 6.669119, test error 55.35
# Epoch   700, train loss 0.234922, train error 8.05,  test loss 7.772967, test error 55.85
# Epoch   800, train loss 0.155480, train error 5.97,  test loss 8.490085, test error 55.67
# Epoch   900, train loss 0.134578, train error 4.47,  test loss 9.316297, test error 55.12
# Training model with  50 hidden variables
# Epoch     0, train loss 2.104673, train error 78.82,  test loss 2.068245, test error 78.50
# Epoch   100, train loss 0.707435, train error 22.57,  test loss 1.576008, test error 50.03
# Epoch   200, train loss 0.350510, train error 11.18,  test loss 2.685858, test error 53.05
# Epoch   300, train loss 0.140719, train error 3.15,  test loss 4.264755, test error 55.40
# Epoch   400, train loss 0.028058, train error 0.00,  test loss 5.864907, test error 55.72
# Epoch   500, train loss 0.012591, train error 0.00,  test loss 6.776371, test error 55.72
# Epoch   600, train loss 0.008121, train error 0.00,  test loss 7.423250, test error 55.70
# Epoch   700, train loss 0.005796, train error 0.00,  test loss 7.881982, test error 55.97
# Epoch   800, train loss 0.004497, train error 0.00,  test loss 8.254643, test error 55.80
# Epoch   900, train loss 0.003647, train error 0.00,  test loss 8.568119, test error 55.80
# Training model with  55 hidden variables
# Epoch     0, train loss 2.038856, train error 76.45,  test loss 1.995769, test error 76.38
# Epoch   100, train loss 0.643631, train error 19.12,  test loss 1.703914, test error 50.65
# Epoch   200, train loss 0.228818, train error 6.03,  test loss 3.083754, test error 55.08
# Epoch   300, train loss 0.042699, train error 0.00,  test loss 4.871787, test error 55.30
# Epoch   400, train loss 0.014648, train error 0.00,  test loss 5.942472, test error 55.62
# Epoch   500, train loss 0.008499, train error 0.00,  test loss 6.584453, test error 55.55
# Epoch   600, train loss 0.005830, train error 0.00,  test loss 7.050191, test error 55.47
# Epoch   700, train loss 0.004357, train error 0.00,  test loss 7.404173, test error 55.60
# Epoch   800, train loss 0.003458, train error 0.00,  test loss 7.693801, test error 55.58
# Epoch   900, train loss 0.002819, train error 0.00,  test loss 7.931312, test error 55.62
# Training model with  60 hidden variables
# Epoch     0, train loss 2.051769, train error 76.57,  test loss 1.996758, test error 75.70
# Epoch   100, train loss 0.521820, train error 15.03,  test loss 1.717354, test error 51.12
# Epoch   200, train loss 0.089721, train error 0.62,  test loss 3.418867, test error 53.83
# Epoch   300, train loss 0.018360, train error 0.00,  test loss 4.635440, test error 53.47
# Epoch   400, train loss 0.009089, train error 0.00,  test loss 5.281933, test error 53.97
# Epoch   500, train loss 0.005792, train error 0.00,  test loss 5.711092, test error 54.15
# Epoch   600, train loss 0.004158, train error 0.00,  test loss 6.034969, test error 54.45
# Epoch   700, train loss 0.003208, train error 0.00,  test loss 6.285454, test error 54.62
# Epoch   800, train loss 0.002581, train error 0.00,  test loss 6.491059, test error 54.53
# Epoch   900, train loss 0.002147, train error 0.00,  test loss 6.671896, test error 54.45
# Training model with  70 hidden variables
# Epoch     0, train loss 2.016438, train error 74.35,  test loss 1.948822, test error 75.07
# Epoch   100, train loss 0.369551, train error 9.10,  test loss 1.893590, test error 50.80
# Epoch   200, train loss 0.035335, train error 0.00,  test loss 3.529184, test error 52.25
# Epoch   300, train loss 0.011543, train error 0.00,  test loss 4.329472, test error 52.42
# Epoch   400, train loss 0.006362, train error 0.00,  test loss 4.776767, test error 52.45
# Epoch   500, train loss 0.004254, train error 0.00,  test loss 5.080370, test error 52.55
# Epoch   600, train loss 0.003146, train error 0.00,  test loss 5.314929, test error 52.33
# Epoch   700, train loss 0.002456, train error 0.00,  test loss 5.500187, test error 52.60
# Epoch   800, train loss 0.002002, train error 0.00,  test loss 5.656393, test error 52.60
# Epoch   900, train loss 0.001679, train error 0.00,  test loss 5.791707, test error 52.55
# Training model with  80 hidden variables
# Epoch     0, train loss 2.027864, train error 74.38,  test loss 1.999066, test error 75.53
# Epoch   100, train loss 0.233509, train error 3.88,  test loss 2.082653, test error 51.65
# Epoch   200, train loss 0.019298, train error 0.00,  test loss 3.435480, test error 52.65
# Epoch   300, train loss 0.007859, train error 0.00,  test loss 3.986233, test error 52.80
# Epoch   400, train loss 0.004661, train error 0.00,  test loss 4.314626, test error 52.80
# Epoch   500, train loss 0.003231, train error 0.00,  test loss 4.546031, test error 52.92
# Epoch   600, train loss 0.002432, train error 0.00,  test loss 4.728625, test error 52.85
# Epoch   700, train loss 0.001931, train error 0.00,  test loss 4.872722, test error 52.95
# Epoch   800, train loss 0.001591, train error 0.00,  test loss 4.995564, test error 52.95
# Epoch   900, train loss 0.001346, train error 0.00,  test loss 5.104615, test error 52.90
# Training model with  90 hidden variables
# Epoch     0, train loss 2.023810, train error 75.75,  test loss 1.949407, test error 74.93
# Epoch   100, train loss 0.153420, train error 1.35,  test loss 2.144339, test error 50.90
# Epoch   200, train loss 0.014882, train error 0.00,  test loss 3.166300, test error 51.42
# Epoch   300, train loss 0.006581, train error 0.00,  test loss 3.587746, test error 51.50
# Epoch   400, train loss 0.004032, train error 0.00,  test loss 3.847642, test error 51.60
# Epoch   500, train loss 0.002832, train error 0.00,  test loss 4.033784, test error 51.40
# Epoch   600, train loss 0.002157, train error 0.00,  test loss 4.178715, test error 51.55
# Epoch   700, train loss 0.001722, train error 0.00,  test loss 4.299443, test error 51.65
# Epoch   800, train loss 0.001426, train error 0.00,  test loss 4.401206, test error 51.72
# Epoch   900, train loss 0.001210, train error 0.00,  test loss 4.487978, test error 51.80
# Training model with 100 hidden variables
# Epoch     0, train loss 2.016586, train error 74.47,  test loss 1.937374, test error 73.80
# Epoch   100, train loss 0.089568, train error 0.15,  test loss 2.298744, test error 51.90
# Epoch   200, train loss 0.011898, train error 0.00,  test loss 3.167527, test error 51.97
# Epoch   300, train loss 0.005563, train error 0.00,  test loss 3.533520, test error 52.53
# Epoch   400, train loss 0.003467, train error 0.00,  test loss 3.760562, test error 52.65
# Epoch   500, train loss 0.002467, train error 0.00,  test loss 3.928379, test error 52.67
# Epoch   600, train loss 0.001892, train error 0.00,  test loss 4.059146, test error 52.70
# Epoch   700, train loss 0.001520, train error 0.00,  test loss 4.166694, test error 52.62
# Epoch   800, train loss 0.001264, train error 0.00,  test loss 4.259669, test error 52.78
# Epoch   900, train loss 0.001077, train error 0.00,  test loss 4.339605, test error 52.78
# Training model with 120 hidden variables
# Epoch     0, train loss 1.959296, train error 73.32,  test loss 1.876576, test error 72.85
# Epoch   100, train loss 0.050615, train error 0.00,  test loss 2.222260, test error 50.58
# Epoch   200, train loss 0.009357, train error 0.00,  test loss 2.829184, test error 50.40
# Epoch   300, train loss 0.004620, train error 0.00,  test loss 3.097759, test error 50.05
# Epoch   400, train loss 0.002962, train error 0.00,  test loss 3.274497, test error 49.97
# Epoch   500, train loss 0.002137, train error 0.00,  test loss 3.403506, test error 50.08
# Epoch   600, train loss 0.001651, train error 0.00,  test loss 3.508464, test error 50.15
# Epoch   700, train loss 0.001334, train error 0.00,  test loss 3.592443, test error 50.12
# Epoch   800, train loss 0.001113, train error 0.00,  test loss 3.664950, test error 50.05
# Epoch   900, train loss 0.000951, train error 0.00,  test loss 3.728047, test error 49.95
# Training model with 140 hidden variables
# Epoch     0, train loss 1.947906, train error 71.72,  test loss 1.881423, test error 73.12
# Epoch   100, train loss 0.034790, train error 0.00,  test loss 2.129800, test error 49.30
# Epoch   200, train loss 0.007909, train error 0.00,  test loss 2.592090, test error 48.90
# Epoch   300, train loss 0.004081, train error 0.00,  test loss 2.813281, test error 49.25
# Epoch   400, train loss 0.002664, train error 0.00,  test loss 2.959347, test error 49.30
# Epoch   500, train loss 0.001942, train error 0.00,  test loss 3.066435, test error 49.35
# Epoch   600, train loss 0.001511, train error 0.00,  test loss 3.153365, test error 49.30
# Epoch   700, train loss 0.001229, train error 0.00,  test loss 3.225505, test error 49.22
# Epoch   800, train loss 0.001029, train error 0.00,  test loss 3.286744, test error 49.28
# Epoch   900, train loss 0.000882, train error 0.00,  test loss 3.340197, test error 49.28
# Training model with 160 hidden variables
# Epoch     0, train loss 1.952371, train error 72.47,  test loss 1.870336, test error 72.65
# Epoch   100, train loss 0.029875, train error 0.00,  test loss 2.155488, test error 49.55
# Epoch   200, train loss 0.007296, train error 0.00,  test loss 2.596673, test error 49.38
# Epoch   300, train loss 0.003814, train error 0.00,  test loss 2.801888, test error 49.28
# Epoch   400, train loss 0.002501, train error 0.00,  test loss 2.940077, test error 49.33
# Epoch   500, train loss 0.001830, train error 0.00,  test loss 3.042525, test error 49.47
# Epoch   600, train loss 0.001429, train error 0.00,  test loss 3.125151, test error 49.42
# Epoch   700, train loss 0.001164, train error 0.00,  test loss 3.193490, test error 49.50
# Epoch   800, train loss 0.000977, train error 0.00,  test loss 3.252375, test error 49.58
# Epoch   900, train loss 0.000838, train error 0.00,  test loss 3.303669, test error 49.62
# Training model with 180 hidden variables
# Epoch     0, train loss 1.909846, train error 69.07,  test loss 1.843234, test error 71.47
# Epoch   100, train loss 0.022873, train error 0.00,  test loss 2.080168, test error 48.60
# Epoch   200, train loss 0.006396, train error 0.00,  test loss 2.436448, test error 48.92
# Epoch   300, train loss 0.003430, train error 0.00,  test loss 2.615268, test error 48.88
# Epoch   400, train loss 0.002281, train error 0.00,  test loss 2.737071, test error 48.75
# Epoch   500, train loss 0.001681, train error 0.00,  test loss 2.827569, test error 48.78
# Epoch   600, train loss 0.001318, train error 0.00,  test loss 2.899999, test error 48.85
# Epoch   700, train loss 0.001077, train error 0.00,  test loss 2.960462, test error 48.70
# Epoch   800, train loss 0.000906, train error 0.00,  test loss 3.012462, test error 48.75
# Epoch   900, train loss 0.000779, train error 0.00,  test loss 3.057493, test error 48.80
# Training model with 200 hidden variables
# Epoch     0, train loss 1.905262, train error 70.68,  test loss 1.818989, test error 71.38
# Epoch   100, train loss 0.021373, train error 0.00,  test loss 2.065666, test error 48.67
# Epoch   200, train loss 0.006050, train error 0.00,  test loss 2.379306, test error 48.65
# Epoch   300, train loss 0.003296, train error 0.00,  test loss 2.544610, test error 48.60
# Epoch   400, train loss 0.002196, train error 0.00,  test loss 2.654704, test error 48.62
# Epoch   500, train loss 0.001625, train error 0.00,  test loss 2.738387, test error 48.58
# Epoch   600, train loss 0.001277, train error 0.00,  test loss 2.805267, test error 48.58
# Epoch   700, train loss 0.001045, train error 0.00,  test loss 2.861666, test error 48.42
# Epoch   800, train loss 0.000880, train error 0.00,  test loss 2.910235, test error 48.47
# Epoch   900, train loss 0.000758, train error 0.00,  test loss 2.952734, test error 48.50
# Training model with 250 hidden variables
# Epoch     0, train loss 1.891307, train error 68.68,  test loss 1.812715, test error 70.03
# Epoch   100, train loss 0.017113, train error 0.00,  test loss 1.925419, test error 47.75
# Epoch   200, train loss 0.005323, train error 0.00,  test loss 2.180850, test error 47.62
# Epoch   300, train loss 0.002970, train error 0.00,  test loss 2.316480, test error 47.47
# Epoch   400, train loss 0.002002, train error 0.00,  test loss 2.410498, test error 47.55
# Epoch   500, train loss 0.001488, train error 0.00,  test loss 2.480578, test error 47.65
# Epoch   600, train loss 0.001175, train error 0.00,  test loss 2.538022, test error 47.65
# Epoch   700, train loss 0.000964, train error 0.00,  test loss 2.585435, test error 47.62
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.626445, test error 47.67
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.662560, test error 47.58
# Training model with 300 hidden variables
# Epoch     0, train loss 1.861437, train error 66.68,  test loss 1.806003, test error 69.85
# Epoch   100, train loss 0.014556, train error 0.00,  test loss 1.860790, test error 46.60
# Epoch   200, train loss 0.004818, train error 0.00,  test loss 2.080674, test error 46.67
# Epoch   300, train loss 0.002731, train error 0.00,  test loss 2.200550, test error 46.47
# Epoch   400, train loss 0.001860, train error 0.00,  test loss 2.283848, test error 46.47
# Epoch   500, train loss 0.001391, train error 0.00,  test loss 2.346041, test error 46.53
# Epoch   600, train loss 0.001102, train error 0.00,  test loss 2.396771, test error 46.47
# Epoch   700, train loss 0.000908, train error 0.00,  test loss 2.439097, test error 46.55
# Epoch   800, train loss 0.000768, train error 0.00,  test loss 2.475850, test error 46.47
# Epoch   900, train loss 0.000664, train error 0.00,  test loss 2.508010, test error 46.38
# Training model with 400 hidden variables
# Epoch     0, train loss 1.852904, train error 66.65,  test loss 1.793654, test error 68.68
# Epoch   100, train loss 0.011709, train error 0.00,  test loss 1.737017, test error 45.72
# Epoch   200, train loss 0.004189, train error 0.00,  test loss 1.908932, test error 45.72
# Epoch   300, train loss 0.002429, train error 0.00,  test loss 2.003475, test error 45.53
# Epoch   400, train loss 0.001674, train error 0.00,  test loss 2.071136, test error 45.78
# Epoch   500, train loss 0.001262, train error 0.00,  test loss 2.122440, test error 45.67
# Epoch   600, train loss 0.001005, train error 0.00,  test loss 2.164136, test error 45.72
# Epoch   700, train loss 0.000830, train error 0.00,  test loss 2.199193, test error 45.90
# Epoch   800, train loss 0.000705, train error 0.00,  test loss 2.229819, test error 45.88
# Epoch   900, train loss 0.000610, train error 0.00,  test loss 2.256343, test error 45.80

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
